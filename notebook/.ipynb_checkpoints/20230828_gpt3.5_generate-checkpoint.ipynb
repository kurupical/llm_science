# %%
import openai
import pandas as pd
import tqdm
import glob

import warnings
warnings.filterwarnings("ignore")

# %%
with open("../apikey/apikey.txt", "r") as f:
    openai.api_key = f.readline().replace("\n", "")

# %%
def query_prompt(prompt, max_tokens=1000):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        messages=[{"role": "user", "content": prompt}],
        max_tokens=max_tokens,
        temperature=0,
    )
    return response["choices"][0]["message"]["content"]

# %%
def get_df(fname):
    def f(categories):
        for cat in categories:
            if "science" in cat:
                return True
            if "physics" in cat:
                return True
            if "chemistry" in cat:
                return True
        return False
    
    def text_preprocess(text):
        return text.replace("===", "\n").replace("==", "\n")

    df = pd.read_parquet(fname)
    df_science = df[df["categories"].apply(f)]
    df_science["text"] = "title: " + df_science["title"] + "\n" + df_science["text"].apply(text_preprocess)
    return df_science.sample(len(df_science)//3)

# %%
files = glob.glob("../data/wikipedia/a.parquet")

# %%
import time

# %%
import pickle

# %%
import json

# %%
from datetime import datetime as dt

# %%
import traceback 
batch_size = 1

def make_prompt(series):
    prompt = f"""
# 依頼
You are a professor at a science university and are creating a test for your students.
Using the given text, create a question in which you select one of the five options for the question text to select the most appropriate statement. Also, extract the portion of the text that provides the basis for your answer.
The output should be an array in json format, with "prompt" as the question text, "A," "B," "C," "D," and "E" as the choices, "answer" as the answer choice, and "basis" as the rationale.
Also, please create one question per text. In other words, the total number of questions created will be one.
# text
## text 1 
{series['text']}


# attention
Please create one question per text. So the total number of problems created will be 1.
"""
    return prompt
texts = []
now_date = dt.now().strftime("%Y%m%d%H%M%S")

for f in files:
    df_science = get_df(f)
    
    for i in tqdm.tqdm(range(len(df_science)), desc=f):
        try:
            series = df_science.iloc[i]
            prompt = make_prompt(series)
            text = query_prompt(prompt)
            text = json.loads(text)
            if type(text) == list:
                text = text[0]
            text["wiki_id"] = series["id"]
            text["original_text"] = series["text"]
            texts.append(text)
        except Exception as e:
            print(e)
            traceback.print_exc()
            print(text)
        if i % 100 == 0:
            pd.DataFrame(texts).to_csv(f"output_gpt3.5_generate/{now_date}.csv")
# Out:
# ../data/wikipedia/a.parquet:   1%|▊                                                                  | 11/925 [01:00<1:28:10,  5.79s/it]

# %%
pd.DataFrame(texts)
# Out:
#                                                prompt  \
# 0   What is the Albert Einstein Professorship in S...
# 1   What was the mission of the Academy of Science...
# 2   What was the purpose of transmitting the song ...
# 3   Which of the following statements about Annett...
# 4     Which genre did Austin Hall primarily write in?
# 5   What is the total undergraduate population of ...
# 6                                  What is academese?
# 7   What was the percentage of the Moon in shadow ...
# 8    What is the main plot of the film August Eighth?
# 9   Which of the following statements is supported...
# 10                     What is Anvita Abbi known for?
# 11  What is the main theme of the book 'All Tomorr...
#
#                                               choices  \
# 0   {'A': 'An endowed professorship in physics est...
# 1                                                 NaN
# 2   {'A': 'To celebrate the 40th anniversary of th...
# 3   {'A': 'Annette Aiello is a professor of botany...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   {'A': 'A young single mother reunites with her...
# 9   [Scientists have discovered a new species of f...
# 10  {'A': 'Her studies on tribal languages and oth...
# 11  {'A': 'The colonization of Mars', 'B': 'The wa...
#
#                                                answer  \
# 0                                                   A
# 1                                                   C
# 2                                                   A
# 3                                                   B
# 4                                                   C
# 5                                                   A
# 6                                                   A
# 7                                                   D
# 8                                                   A
# 9   The World Meteorological Organization has anno...
# 10                                                  A
# 11                                                  C
#
#                                                 basis   wiki_id  \
# 0   The Albert Einstein Professorship in Science i...  70302156
# 1   In 1856, the Academy's mission was to promote ...  25865948
# 2   The transmission of the song 'Across the Unive...  24891124
# 3   In 1975 she obtained an MA in biology from Har...  64378727
# 4   Austin Hall primarily wrote in the genres of s...  16994153
# 5   Alfred University has a total undergraduate po...    345573
# 6   Academese is a term referring to unnecessary j...  68617312
# 7   The text states that during the April 1903 lun...  22068713
# 8   The film tells the story of a young single mot...  34760284
# 9   On June 23, the World Meteorological Organizat...  64647168
# 10  Anvita Abbi is known for her studies on tribal...  44233542
# 11  The book 'All Tomorrows' explores a hypothetic...  51507225
#
#                                         original_text  \
# 0   title: Albert Einstein Professorship in Scienc...
# 1   title: Academy of Science, St. Louis\nThe Acad...
# 2   title: Across the Universe (message)\nAcross t...
# 3   title: Annette Aiello\nAnnette A. Aiello (born...
# 4   title: Austin Hall (writer)\n{{Infobox writer ...
# 5   title: Alfred University\nAlfred University is...
# 6   title: Academese\nAcademese is a term referrin...
# 7   title: April 1903 lunar eclipse\nA partial lun...
# 8   title: August Eighth\nAugust Eighth (, transli...
# 9   title: April–June 2020 in science\nThis articl...
# 10  title: Anvita Abbi\nProfessor Anvita Abbi (bor...
# 11  title: All Tomorrows\nAll Tomorrows: A Billion...
#
#                                               A  \
# 0                                           NaN
# 1     To promote science education in St. Louis
# 2                                           NaN
# 3                                           NaN
# 4                                       Mystery
# 5                  Approximately 1,600 students
# 6   Unnecessary jargon associated with academia
# 7                                           50%
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
#
#                                                     B  \
# 0                                                 NaN
# 1   To explore the West and discover natural resou...
# 2                                                 NaN
# 3                                                 NaN
# 4                                             Romance
# 5                        Approximately 2,000 students
# 6         A form of power relations between academics
# 7                                                 75%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
#                                                    C  \
# 0                                                NaN
# 1   To advance scientific research in various fields
# 2                                                NaN
# 3                                                NaN
# 4                                    Science fiction
# 5                       Approximately 2,500 students
# 6                  Complex but necessary terminology
# 7                                                90%
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
#
#                                                     D  \
# 0                                                 NaN
# 1   To establish a museum of science and natural h...
# 2                                                 NaN
# 3                                                 NaN
# 4                                  Historical fiction
# 5                        Approximately 3,000 students
# 6                      A synonym for academic writing
# 7                                              96.77%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
#                                                     E
# 0                                                 NaN
# 1   To publish scientific journals on the natural ...
# 2                                                 NaN
# 3                                                 NaN
# 4                                           Biography
# 5                        Approximately 3,500 students
# 6                    A stereotype of academic writing
# 7                                                100%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN

# %%
df_science = get_df(files[0])
df_science[df_science["id"] == '29637793']
# Out:
# Empty DataFrame
# Columns: [id, title, text, categories]
# Index: []

# %%
df_science
# Out:
#               id                          title  \
# 368626   1908395               Artificial brain
# 34268   10410698            Abdul Amir al-Jamri
# 233077   1958222                   Amyloid beta
# 9870     3621668     A Woman of the Iron People
# 139719  38366604                  Albert Spaier
# ...          ...                            ...
# 62685    4474244             Actuarial reserves
# 357456   4260564                     Arrival II
# 391514  32894329                Astrobiophysics
# 10000    2824171  A World of Difference (novel)
# 264660   4468753           Andy Duncan (writer)
#
#                                                      text  \
# 368626  title: Artificial brain\nAn artificial brain (...
# 34268   title: Abdul Amir al-Jamri\nSheikh Abdul Amir ...
# 233077  title: Amyloid beta\nAmyloid beta (Aβ or Abeta...
# 9870    title: A Woman of the Iron People\nA Woman of ...
# 139719  title: Albert Spaier\nAlbert Spaier (9 July 18...
# ...                                                   ...
# 62685   title: Actuarial reserves\nIn insurance, an ac...
# 357456  title: Arrival II\nArrival ll (alternatively t...
# 391514  title: Astrobiophysics\nAstrobiophysics is a f...
# 10000   title: A World of Difference (novel)\nA World ...
# 264660  title: Andy Duncan (writer)\nthumb|Andy Duncan...
#
#                                                categories
# 368626  [Computational neuroscience, Robotics, Emergin...
# 34268   [1938 births, 2006 deaths, Deaths from kidney ...
# 233077  [Peptides, Molecular neuroscience, Alzheimer's...
# 9870    [1991 American novels, 1991 science fiction no...
# 139719  [1883 births, 1934 deaths, Writers from Iași, ...
# ...                                                   ...
# 62685   [Actuarial science, Capital requirement de:Dec...
# 357456  [1998 films, 1998 science fiction films, Ameri...
# 391514                       [Astrophysics, Biophysics .]
# 10000   [1990 American novels, Novels set during the C...
# 264660  [1964 births, Living people, 21st-century Amer...
#
# [277 rows x 4 columns]
