# %%
import pandas as pd

# %%
df_gpt = pd.read_parquet("../output/context_pipeline/stage1/exp002.py/20230906090758_all-MiniLM-L6-v2_wikionly_text_targetprompt_and_choice_all_text/searched_index_train.parquet")

# %%
df_wiki = pd.read_parquet("../output/context_pipeline/stage1/exp002.py/20230906054359_all-MiniLM-L6-v2_wikionly_text_targetprompt_and_choice_all_text/searched_index_train.parquet")

# %%
for i in range(100):
    series = df_gpt.iloc[i]
    print(f"""
-------------------------
prompt: {series['prompt']}
A: {series['A']}
B: {series['B']}
C: {series['C']}
D: {series['D']}
E: {series['E']}
ans: {series['answer']}
basis: {series['basis']}
""")
# Out:
# -------------------------
# prompt: Who became the editor-in-chief of the Annals of Mathematical Statistics in 1938?
# A: Samuel Wilks
# B: Fisher
# C: Neyman
# D: Cramér
# E: Hotelling
# ans: A
# basis: According to the given text, Samuel Wilks became the editor-in-chief of the Annals of Mathematical Statistics in 1938.
#
#
# -------------------------
# prompt: What is abortive initiation in genetic transcription?
# A: The process in which RNA polymerase binds to a DNA promoter and enters into cycles of synthesis of short mRNA transcripts which are released before the transcription complex leaves the promoter.
# B: The process in which RNA polymerase escapes the promoter and enters into the elongation step of transcription.
# C: The process in which RNA polymerase unwinds one turn of DNA surrounding the transcription start site to yield an RNA polymerase-promoter open complex.
# ...

# %%
for i in range(10):
    series = df_wiki.iloc[i]
    print(f"""
-------------------------
prompt: {series['prompt']}
A: {series['A']}
B: {series['B']}
C: {series['C']}
D: {series['D']}
E: {series['E']}
ans: {series['answer']}
""")
# Out:
# -------------------------
# prompt: In relation to Eunice Fay McKenzie's career, which statement accurately reflects her most notable work?
# A: McKenzie showcased her singing talents in numerous musical productions, garnering critical acclaim.
# B: McKenzie is primarily remembered for her starring roles opposite Gene Autry in popular Western films of the 1940s.
# C: McKenzie gained recognition for her role as a child actress in a series of iconic silent films.
# D: McKenzie's collaborations with director Blake Edwards were instrumental in her rise to fame.
# E: McKenzie's successful career in sound films continued into adulthood, becoming known for her versatile acting abilities.
# ans: B
#
#
# -------------------------
# prompt: How does Modified Newtonian Dynamics (MOND) impact the observed "missing baryonic mass" discrepancy in galaxy clusters, according to the provided excerpt from Wikipedia?
# ...
